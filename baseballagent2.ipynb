# %%
# Data cleaning and preprocessing
#Using pybaseball 2024 MLB data

# %%
# !pip install pybaseball
# Out:
# Collecting pybaseball
#   Downloading pybaseball-2.2.7-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (1.26.4)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (2.2.3)
# Requirement already satisfied: beautifulsoup4>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (4.13.3)
# Requirement already satisfied: requests>=2.18.1 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (2.32.3)
# Requirement already satisfied: lxml>=4.2.1 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (5.3.1)
# Requirement already satisfied: pyarrow>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (19.0.1)
# Collecting pygithub>=1.51 (from pybaseball)
#   Downloading PyGithub-2.6.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (1.15.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (3.7.5)
# Requirement already satisfied: tqdm>=4.50.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (4.67.1)
# Requirement already satisfied: attrs>=20.3.0 in /usr/local/lib/python3.11/dist-packages (from pybaseball) (25.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.0->pybaseball) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.0->pybaseball) (4.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pybaseball) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.13.0->pybaseball) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.13.0->pybaseball) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.13.0->pybaseball) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.13.0->pybaseball) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.13.0->pybaseball) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.13.0->pybaseball) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.3->pybaseball) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.3->pybaseball) (2025.2)
# Collecting pynacl>=1.4.0 (from pygithub>=1.51->pybaseball)
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: pyjwt>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (2.10.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from pygithub>=1.51->pybaseball) (2.3.0)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.11/dist-packages (from pygithub>=1.51->pybaseball) (1.2.18)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.1->pybaseball) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.1->pybaseball) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.1->pybaseball) (2025.1.31)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball) (44.0.2)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pynacl>=1.4.0->pygithub>=1.51->pybaseball) (1.17.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pybaseball) (1.17.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from Deprecated->pygithub>=1.51->pybaseball) (1.17.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.13.0->pybaseball) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.13.0->pybaseball) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.13.0->pybaseball) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.13.0->pybaseball) (2024.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub>=1.51->pybaseball) (2.22)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.13.0->pybaseball) (2024.2.0)
# Downloading pybaseball-2.2.7-py3-none-any.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.1/426.1 kB 5.8 MB/s eta 0:00:0000:0100:01
# Downloading PyGithub-2.6.1-py3-none-any.whl (410 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 20.9 MB/s eta 0:00:00
# Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 38.9 MB/s eta 0:00:00
# Installing collected packages: pynacl, pygithub, pybaseball
# Successfully installed pybaseball-2.2.7 pygithub-2.6.1 pynacl-1.5.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pybaseball as pyb

# %%
from pybaseball import pitching_stats

pitching_data = pitching_stats(2024, qual=100)
pitching_data
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#       IDfg  Season             Name Team  Age   W   L  WAR   ERA   G  ...  \
# 2    10603    2024       Chris Sale  ATL   35  18   3  6.4  2.38  29  ...
# 3    22267    2024     Tarik Skubal  DET   27  18   4  5.9  2.39  31  ...
# 4    10310    2024     Zack Wheeler  PHI   34  16   7  5.4  2.57  32  ...
# 20   21846    2024      Cole Ragans  KCR   26  11   9  4.9  3.14  32  ...
# 35   18525    2024      Dylan Cease  SDP   28  14  11  4.8  3.47  33  ...
# ..     ...     ...              ...  ...  ...  ..  ..  ...   ...  ..  ...
# 62   11589    2024       Jose Urena  TEX   32   5   8  0.1  3.80  33  ...
# 122   6632    2024  Carlos Carrasco  CLE   37   3  10  0.1  5.64  21  ...
# 124  18498    2024      Kenta Maeda  DET   36   3   7  0.0  6.09  29  ...
# 73   19990    2024     Bryse Wilson  MIL   26   5   4 -0.2  4.04  34  ...
# 116  17735    2024  Tyler Alexander  TBR   29   6   5 -0.6  5.10  23  ...
#
#      Pit+ FC  Stf+ FS  Loc+ FS  Pit+ FS  Stuff+  Location+  Pitching+  \
# 2        NaN      NaN      NaN      NaN     104        111        110
# 3        NaN      NaN      NaN      NaN     112        100        112
# 4       96.0     94.0    101.0     91.0     110        104        113
# 20     100.0      NaN      NaN      NaN     110         99        110
# 35      92.0      NaN      NaN      NaN     110        104        113
# ..       ...      ...      ...      ...     ...        ...        ...
# 62       NaN      NaN      NaN      NaN      93        100         96
# 122      NaN      NaN      NaN      NaN      84         98         86
# 124    109.0     98.0    112.0    110.0      92        104         99
# 73     100.0      NaN      NaN      NaN     102         98         98
# 116    100.0      NaN      NaN      NaN     101        106        102
#
#      Stf+ FO  Loc+ FO  Pit+ FO
# 2        NaN      NaN      NaN
# 3        NaN      NaN      NaN
# 4        NaN      NaN      NaN
# 20       NaN      NaN      NaN
# 35       NaN      NaN      NaN
# ..       ...      ...      ...
# 62       NaN      NaN      NaN
# 122      NaN      NaN      NaN
# 124      NaN      NaN      NaN
# 73       NaN      NaN      NaN
# 116      NaN      NaN      NaN
#
# [126 rows x 393 columns]

# %%
statcast_data2 = pyb.statcast(start_dt='2024-03-30', end_dt='2024-8-30')
statcast_data2
# Out:
# This is a large query, it may take a moment to complete
# /usr/local/lib/python3.11/dist-packages/pybaseball/statcast.py:50: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
#   warnings.warn(_OVERSIZE_WARNING)
#   0%|          | 0/154 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   1%|          | 1/154 [00:00<01:58,  1.29it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   1%|▏         | 2/154 [00:05<08:06,  3.20s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   2%|▏         | 3/154 [00:07<06:23,  2.54s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   3%|▎         | 4/154 [00:07<04:18,  1.72s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   3%|▎         | 5/154 [00:08<03:04,  1.24s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   5%|▌         | 8/154 [00:09<01:30,  1.61it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   6%|▌         | 9/154 [00:09<01:26,  1.69it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   6%|▋         | 10/154 [00:11<02:09,  1.11it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   7%|▋         | 11/154 [00:13<02:48,  1.18s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   8%|▊         | 12/154 [00:15<03:20,  1.41s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   8%|▊         | 13/154 [00:16<02:56,  1.25s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   9%|▉         | 14/154 [00:16<02:23,  1.02s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  10%|▉         | 15/154 [00:17<02:16,  1.02it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  11%|█         | 17/154 [00:17<01:25,  1.61it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  12%|█▏        | 18/154 [00:18<01:25,  1.58it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  12%|█▏        | 19/154 [00:19<01:42,  1.32it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  13%|█▎        | 20/154 [00:21<02:37,  1.17s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  14%|█▍        | 22/154 [00:23<02:20,  1.07s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  15%|█▍        | 23/154 [00:24<02:09,  1.01it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  16%|█▌        | 24/154 [00:25<01:58,  1.10it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  17%|█▋        | 26/154 [00:25<01:14,  1.71it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  18%|█▊        | 27/154 [00:26<01:11,  1.77it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  19%|█▉        | 29/154 [00:28<01:37,  1.28it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  19%|█▉        | 30/154 [00:29<01:49,  1.14it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  20%|██        | 31/154 [00:31<02:09,  1.05s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  21%|██        | 32/154 [00:32<02:28,  1.22s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  21%|██▏       | 33/154 [00:33<02:16,  1.13s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  22%|██▏       | 34/154 [00:34<01:48,  1.11it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  23%|██▎       | 35/154 [00:35<01:50,  1.08it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  23%|██▎       | 36/154 [00:36<02:19,  1.19s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  25%|██▍       | 38/154 [00:37<01:37,  1.18it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  25%|██▌       | 39/154 [00:38<01:33,  1.23it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  26%|██▌       | 40/154 [00:40<01:51,  1.02it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  27%|██▋       | 41/154 [00:41<02:02,  1.08s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  27%|██▋       | 42/154 [00:42<01:54,  1.02s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  29%|██▊       | 44/154 [00:43<01:35,  1.15it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  29%|██▉       | 45/154 [00:44<01:41,  1.08it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  30%|██▉       | 46/154 [00:45<01:36,  1.12it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  31%|███       | 48/154 [00:46<01:07,  1.57it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  32%|███▏      | 49/154 [00:49<02:20,  1.34s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  32%|███▏      | 50/154 [00:50<01:52,  1.08s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  34%|███▍      | 52/154 [00:50<01:19,  1.28it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  34%|███▍      | 53/154 [00:51<01:19,  1.27it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  35%|███▌      | 54/154 [00:52<01:30,  1.11it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  36%|███▌      | 55/154 [00:53<01:28,  1.12it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  37%|███▋      | 57/154 [00:55<01:23,  1.17it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  38%|███▊      | 59/154 [00:57<01:21,  1.17it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  39%|███▉      | 60/154 [00:58<01:14,  1.26it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
# ...
#  86%|████████▋ | 133/154 [02:02<00:25,  1.21s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  87%|████████▋ | 134/154 [02:03<00:20,  1.01s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  88%|████████▊ | 135/154 [02:03<00:15,  1.23it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  88%|████████▊ | 136/154 [02:04<00:14,  1.22it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  90%|████████▉ | 138/154 [02:06<00:14,  1.13it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  90%|█████████ | 139/154 [02:07<00:12,  1.16it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  91%|█████████ | 140/154 [02:09<00:14,  1.07s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  92%|█████████▏| 141/154 [02:09<00:12,  1.07it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  92%|█████████▏| 142/154 [02:10<00:12,  1.05s/it]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  93%|█████████▎| 143/154 [02:11<00:10,  1.05it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  94%|█████████▎| 144/154 [02:12<00:08,  1.23it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  94%|█████████▍| 145/154 [02:13<00:07,  1.20it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#  95%|█████████▍| 146/154 [02:13<00:05,  1.42it/s]/usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# /usr/local/lib/python3.11/dist-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# 100%|██████████| 154/154 [02:18<00:00,  1.11it/s]
# /usr/local/lib/python3.11/dist-packages/pybaseball/statcast.py:85: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_data = pd.concat(dataframe_list, axis=0).convert_dtypes(convert_string=False)
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 2210         SL 2024-08-30           86.6           2.87           5.35
# 2288         SL 2024-08-30           85.0           3.15            5.3
# 2304         FF 2024-08-30           96.7           2.83           5.44
# 2398         FF 2024-08-30           94.7           2.96           5.33
# 2456         FF 2024-08-30           96.5            2.9           5.26
# ...         ...        ...            ...            ...            ...
# 4101         FF 2024-03-30           91.4           0.57           6.16
# 4259         FF 2024-03-30           91.1           0.46           6.21
# 4319         CH 2024-03-30           81.8           0.88           6.14
# 4583         CH 2024-03-30           81.7           0.89           6.09
# 4703         FF 2024-03-30           90.6           0.63           6.25
#
#          player_name  batter  pitcher     events      description  ...  \
# 2210  Banda, Anthony  641645   607455  field_out    hit_into_play  ...
# 2288  Banda, Anthony  641645   607455        NaN    called_strike  ...
# 2304  Banda, Anthony  641645   607455        NaN    called_strike  ...
# 2398  Banda, Anthony  682998   607455  field_out    hit_into_play  ...
# 2456  Banda, Anthony  682998   607455        NaN             ball  ...
# ...              ...     ...      ...        ...              ...  ...
# 4101  Bradford, Cody  663538   674003  strikeout    called_strike  ...
# 4259  Bradford, Cody  663538   674003        NaN             foul  ...
# 4319  Bradford, Cody  663538   674003        NaN             foul  ...
# 4583  Bradford, Cody  663538   674003        NaN  swinging_strike  ...
# 4703  Bradford, Cody  663538   674003        NaN             ball  ...
#
#       n_thruorder_pitcher  n_priorpa_thisgame_player_at_bat  \
# 2210                    1                                 0
# 2288                    1                                 0
# 2304                    1                                 0
# 2398                    1                                 4
# 2456                    1                                 4
# ...                   ...                               ...
# 4101                    1                                 0
# 4259                    1                                 0
# 4319                    1                                 0
# 4583                    1                                 0
# 4703                    1                                 0
#
#       pitcher_days_since_prev_game  batter_days_since_prev_game  \
# 2210                             1                            2
# 2288                             1                            2
# 2304                             1                            2
# 2398                             1                            1
# 2456                             1                            1
# ...                            ...                          ...
# 4101                          <NA>                            2
# 4259                          <NA>                            2
# 4319                          <NA>                            2
# 4583                          <NA>                            2
# 4703                          <NA>                            2
#
#       pitcher_days_until_next_game batter_days_until_next_game  \
# 2210                             3                           1
# 2288                             3                           1
# 2304                             3                           1
# 2398                             3                           1
# 2456                             3                           1
# ...                            ...                         ...
# 4101                             6                           1
# 4259                             6                           1
# 4319                             6                           1
# 4583                             6                           1
# 4703                             6                           1
#
#      api_break_z_with_gravity api_break_x_arm api_break_x_batter_in arm_angle
# 2210                      2.7           -0.77                 -0.77      36.6
# 2288                     2.81            -0.6                  -0.6      32.6
# 2304                     1.15            0.89                  0.89      37.7
# 2398                     1.27             0.9                   0.9      30.9
# 2456                     1.34             1.2                   1.2      32.7
# ...                       ...             ...                   ...       ...
# 4101                     1.14            0.33                 -0.33      56.4
# 4259                     1.12            0.74                 -0.74      64.8
# 4319                     2.03            1.18                 -1.18      47.2
# 4583                     2.37            1.32                 -1.32      48.0
# 4703                     1.15            0.59                 -0.59      55.3
#
# [584974 rows x 113 columns]

# %%
statcast_data2

# %%
statcast_data2.columns.to_list()

# %%
filtered_data = statcast_data2[[
    'pitch_type', 'release_speed', 'inning', 'outs_when_up', 'stand', 'p_throws',
    'description','balls','strikes','bb_type','hit_location','events','player_name'
]]

# %%
filtered_data.head()

# %%
filtered_data['events'].unique()

# %%
filtered_data['pitch_type'].unique()
# Out:
# array(['SL', 'FF', 'SI', 'CH', 'ST', 'FC', 'CU', 'KC', 'FS', 'FA', 'KN',
#        'SV', 'SC', 'PO', 'EP', 'CS', nan, 'FO'], dtype=object)

# %%
 rows_with_na = filtered_data[filtered_data.isna().any(axis=1)]
 rows_with_na
# Out:
#      pitch_type  release_speed  inning  outs_when_up stand p_throws  \
# 2275         SL           85.0       9             2     L        L
# 2312         FF           96.7       9             2     L        L
# 2443         FF           96.5       9             1     L        L
# 2497         FF           96.4       9             1     L        L
# 2571         SL           85.2       9             1     L        L
# ...         ...            ...     ...           ...   ...      ...
# 4107         FF           91.4       1             0     R        L
# 4141         FF           91.1       1             0     R        L
# 4342         CH           81.8       1             0     R        L
# 4588         CH           81.7       1             0     R        L
# 4688         FF           90.6       1             0     R        L
#
#           description  balls  strikes bb_type  hit_location     events  \
# 2275    called_strike      0        1     NaN          <NA>        NaN
# 2312    called_strike      0        0     NaN          <NA>        NaN
# 2443             ball      2        1     NaN          <NA>        NaN
# 2497    called_strike      2        0     NaN          <NA>        NaN
# 2571             ball      1        0     NaN          <NA>        NaN
# ...               ...    ...      ...     ...           ...        ...
# 4107    called_strike      1        2     NaN             2  strikeout
# 4141             foul      1        2     NaN          <NA>        NaN
# 4342             foul      1        1     NaN          <NA>        NaN
# 4588  swinging_strike      1        0     NaN          <NA>        NaN
# 4688             ball      0        0     NaN          <NA>        NaN
#
#          player_name
# 2275  Banda, Anthony
# 2312  Banda, Anthony
# 2443  Banda, Anthony
# 2497  Banda, Anthony
# 2571  Banda, Anthony
# ...              ...
# 4107  Bradford, Cody
# 4141  Bradford, Cody
# 4342  Bradford, Cody
# 4588  Bradford, Cody
# 4688  Bradford, Cody
#
# [487116 rows x 13 columns]

# %%
filtered_data['Count']= filtered_data['balls'].astype(str) + '-' + filtered_data['strikes'].astype(str)

# %%
filtered_data.head()

# %%
filtered_data.drop(columns=['balls','strikes'],inplace=True)

# %%
filtered_data

# %%
filtered_data['description'].unique()
# Out:
# array(['hit_into_play', 'called_strike', 'ball', 'swinging_strike',
#        'foul', 'blocked_ball', 'foul_tip', 'swinging_strike_blocked',
#        'hit_by_pitch', 'bunt_foul_tip', 'foul_bunt', 'missed_bunt',
#        'pitchout'], dtype=object)

# %%
filtered_data['bb_type'].unique()
# Out:
# array(['fly_ball', nan, 'popup', 'ground_ball', 'line_drive'],
#       dtype=object)

# %%
filtered_data['events'].unique()
# Out:
# array(['field_out', nan, 'home_run', 'single', 'strikeout', 'double',
#        'walk', 'grounded_into_double_play', 'hit_by_pitch', 'sac_fly',
#        'sac_fly_double_play', 'force_out', 'truncated_pa', 'field_error',
#        'triple', 'catcher_interf', 'fielders_choice', 'sac_bunt',
#        'double_play', 'strikeout_double_play', 'fielders_choice_out',
#        'triple_play'], dtype=object)

# %%
def combine_result(row):
    # Use 'events' if it exists
    if pd.notna(row['events']):
        return row['events']
    # If 'events' is missing, try 'description'
    elif pd.notna(row['description']):
        return row['description']
    # If both are missing, use 'bb_type'
    elif pd.notna(row['bb_type']):
        return row['bb_type']
    else:
        return 'unknown'

# Apply the function
filtered_data['Pitch_result'] = filtered_data.apply(combine_result, axis=1)
# Out:
# /tmp/ipykernel_31/797094344.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Pitch_result'] = filtered_data.apply(combine_result, axis=1)

# %%
filtered_data.head()
# Out:
#      pitch_type  release_speed  inning  outs_when_up stand p_throws  \
# 2212         SL           86.6       9             2     L        L
# 2262         SL           85.0       9             2     L        L
# 2348         FF           96.7       9             2     L        L
# 2379         FF           94.7       9             1     L        L
# 2430         FF           96.5       9             1     L        L
#
#         description  balls  strikes   bb_type  hit_location     events  \
# 2212  hit_into_play      0        2  fly_ball             7  field_out
# 2262  called_strike      0        1       NaN          <NA>        NaN
# 2348  called_strike      0        0       NaN          <NA>        NaN
# 2379  hit_into_play      3        1     popup             5  field_out
# 2430           ball      2        1       NaN          <NA>        NaN
#
#          player_name   Pitch_result
# 2212  Banda, Anthony      field_out
# 2262  Banda, Anthony  called_strike
# 2348  Banda, Anthony  called_strike
# 2379  Banda, Anthony      field_out
# 2430  Banda, Anthony           ball

# %%
filtered_data.drop(columns=['events','description','bb_type'],inplace=True)
# Out:
# /tmp/ipykernel_31/1607291590.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data.drop(columns=['events','description','bb_type'],inplace=True)

# %%
filtered_data['Pitch_result'].unique()
# Out:
# array(['field_out', 'called_strike', 'ball', 'home_run',
#        'swinging_strike', 'single', 'foul', 'blocked_ball', 'foul_tip',
#        'strikeout', 'double', 'walk', 'grounded_into_double_play',
#        'hit_by_pitch', 'bunt_foul_tip', 'sac_fly', 'sac_fly_double_play',
#        'force_out', 'truncated_pa', 'field_error', 'triple', 'foul_bunt',
#        'swinging_strike_blocked', 'catcher_interf', 'fielders_choice',
#        'sac_bunt', 'double_play', 'strikeout_double_play', 'missed_bunt',
#        'fielders_choice_out', 'pitchout', 'triple_play'], dtype=object)

# %%
filtered_data.head()
# Out:
#      pitch_type  release_speed  inning  outs_when_up stand p_throws  balls  \
# 2245         SL           86.6       9             2     L        L      0
# 2275         SL           85.0       9             2     L        L      0
# 2312         FF           96.7       9             2     L        L      0
# 2360         FF           94.7       9             1     L        L      3
# 2443         FF           96.5       9             1     L        L      2
#
#       strikes  hit_location     player_name   Pitch_result
# 2245        2             7  Banda, Anthony      field_out
# 2275        1          <NA>  Banda, Anthony  called_strike
# 2312        0          <NA>  Banda, Anthony  called_strike
# 2360        1             5  Banda, Anthony      field_out
# 2443        1          <NA>  Banda, Anthony           ball

# %%
filtered_data.drop(columns=['hit_location'],inplace=True)
# Out:
# /tmp/ipykernel_31/1156156115.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data.drop(columns=['hit_location'],inplace=True)

# %%
filtered_data
# Out:
#      pitch_type  release_speed  inning  outs_when_up stand p_throws  balls  \
# 2212         SL           86.6       9             2     L        L      0
# 2262         SL           85.0       9             2     L        L      0
# 2348         FF           96.7       9             2     L        L      0
# 2379         FF           94.7       9             1     L        L      3
# 2430         FF           96.5       9             1     L        L      2
# ...         ...            ...     ...           ...   ...      ...    ...
# 4054         FF           91.4       1             0     R        L      1
# 4196         FF           91.1       1             0     R        L      1
# 4440         CH           81.8       1             0     R        L      1
# 4475         CH           81.7       1             0     R        L      1
# 4651         FF           90.6       1             0     R        L      0
#
#       strikes     player_name     Pitch_result
# 2212        2  Banda, Anthony        field_out
# 2262        1  Banda, Anthony    called_strike
# 2348        0  Banda, Anthony    called_strike
# 2379        1  Banda, Anthony        field_out
# 2430        1  Banda, Anthony             ball
# ...       ...             ...              ...
# 4054        2  Bradford, Cody        strikeout
# 4196        2  Bradford, Cody             foul
# 4440        1  Bradford, Cody             foul
# 4475        0  Bradford, Cody  swinging_strike
# 4651        0  Bradford, Cody             ball
#
# [584974 rows x 10 columns]

# %%
filtered_data.isna().sum()
# Out:
# pitch_type       285
# release_speed    286
# inning             0
# outs_when_up       0
# stand              0
# p_throws           0
# balls              0
# strikes            0
# player_name        0
# Pitch_result       0
# dtype: int64

# %%
 rows_with_na2 = filtered_data[filtered_data.isna().any(axis=1)]
 rows_with_na2
# Out:
#      pitch_type  release_speed  inning  outs_when_up stand p_throws  balls  \
# 1915        NaN           <NA>       2             1     R        L      2
# 1974        NaN           <NA>       2             1     R        L      2
# 1978        NaN           <NA>       2             1     R        L      1
# 2042        NaN           <NA>       2             1     R        L      1
# 2103        NaN           <NA>       2             1     R        L      1
# ...         ...            ...     ...           ...   ...      ...    ...
# 2972        NaN           <NA>       1             2     L        R      2
# 9           NaN           <NA>       5             1     R        R      2
# 4061        NaN           <NA>       1             0     L        R      1
# 3324        NaN           <NA>       7             0     R        L      2
# 3449        NaN           <NA>       7             0     R        L      2
#
#       strikes      player_name     Pitch_result
# 1915        2    Skubal, Tarik             foul
# 1974        2    Skubal, Tarik             foul
# 1978        2    Skubal, Tarik             ball
# 2042        1    Skubal, Tarik  swinging_strike
# 2103        0    Skubal, Tarik  swinging_strike
# ...       ...              ...              ...
# 2972        2   Hudson, Dakota             ball
# 9           0    Littell, Zack           single
# 4061        2  López, Reynaldo        strikeout
# 3324        2    Fleming, Josh        field_out
# 3449        2    Fleming, Josh             foul
#
# [286 rows x 10 columns]

# %%
filtered_data['release_speed'] = filtered_data['release_speed'].fillna(filtered_data['release_speed'].median())
# Out:
# /tmp/ipykernel_31/2418452833.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['release_speed'] = filtered_data['release_speed'].fillna(filtered_data['release_speed'].median())

# %%
filtered_data['pitch_type'] = filtered_data['pitch_type'].fillna(filtered_data['pitch_type'].mode()[0])
# Out:
# /tmp/ipykernel_31/2524479105.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['pitch_type'] = filtered_data['pitch_type'].fillna(filtered_data['pitch_type'].mode()[0])

# %%
filtered_data.dropna(inplace=True)
# Out:
# <ipython-input-15-d4050551feac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data.dropna(inplace=True)

# %%
filtered_data.drop(columns=['player_name'],inplace=True)
# Out:
# /tmp/ipykernel_31/2709668243.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data.drop(columns=['player_name'],inplace=True)

# %%
filtered_data
# Out:
#      pitch_type  release_speed  inning  outs_when_up stand p_throws  balls  \
# 2212         SL           86.6       9             2     L        L      0
# 2262         SL           85.0       9             2     L        L      0
# 2348         FF           96.7       9             2     L        L      0
# 2379         FF           94.7       9             1     L        L      3
# 2430         FF           96.5       9             1     L        L      2
# ...         ...            ...     ...           ...   ...      ...    ...
# 4054         FF           91.4       1             0     R        L      1
# 4196         FF           91.1       1             0     R        L      1
# 4440         CH           81.8       1             0     R        L      1
# 4475         CH           81.7       1             0     R        L      1
# 4651         FF           90.6       1             0     R        L      0
#
#       strikes     Pitch_result
# 2212        2        field_out
# 2262        1    called_strike
# 2348        0    called_strike
# 2379        1        field_out
# 2430        1             ball
# ...       ...              ...
# 4054        2        strikeout
# 4196        2             foul
# 4440        1             foul
# 4475        0  swinging_strike
# 4651        0             ball
#
# [584974 rows x 9 columns]

# %%
filtered_data['Pitch_result'].unique()
#encode for one hot vectors
# Out:
# array(['field_out', 'called_strike', 'ball', 'home_run',
#        'swinging_strike', 'single', 'foul', 'blocked_ball', 'foul_tip',
#        'strikeout', 'double', 'walk', 'grounded_into_double_play',
#        'hit_by_pitch', 'bunt_foul_tip', 'sac_fly', 'sac_fly_double_play',
#        'force_out', 'truncated_pa', 'field_error', 'triple', 'foul_bunt',
#        'swinging_strike_blocked', 'catcher_interf', 'fielders_choice',
#        'sac_bunt', 'double_play', 'strikeout_double_play', 'missed_bunt',
#        'fielders_choice_out', 'pitchout', 'triple_play'], dtype=object)

# %%
filtered_data['Pitch_result'].value_counts()
# Out:
# Pitch_result
# ball                         183522
# foul                         105833
# called_strike                 87960
# field_out                     61106
# swinging_strike               40111
# strikeout                     33563
# single                        21319
# walk                          11855
# blocked_ball                  11409
# double                         6495
# home_run                       4545
# foul_tip                       3734
# force_out                      2887
# grounded_into_double_play      2660
# hit_by_pitch                   1704
# sac_fly                        1027
# foul_bunt                       990
# field_error                     916
# swinging_strike_blocked         854
# triple                          593
# sac_bunt                        378
# fielders_choice                 300
# double_play                     289
# fielders_choice_out             260
# truncated_pa                    255
# missed_bunt                     168
# strikeout_double_play            93
# catcher_interf                   84
# pitchout                         41
# bunt_foul_tip                    12
# sac_fly_double_play              10
# triple_play                       1
# Name: count, dtype: int64

# %%
# Mapping dictionary
outcome_mapping = {
    # Strikes
    'called_strike': 'strike',
    'swinging_strike': 'strike',
    'swinging_strike_blocked': 'strike',
    'foul': 'strike',
    'foul_tip': 'strike',
    'bunt_foul_tip': 'strike',
    'foul_bunt': 'strike',
    'missed_bunt': 'strike',

    # Balls
    'ball': 'ball',
    'blocked_ball': 'ball',
    'pitchout': 'ball',

    # Hits
    'single': 'hit',
    'double': 'hit',
    'triple': 'hit',
    'home_run': 'hit',

    # Outs
    'field_out': 'out',
    'strikeout': 'out',
    'strikeout_double_play': 'out',
    'force_out': 'out',
    'grounded_into_double_play': 'out',
    'double_play': 'out',
    'triple_play': 'out',
    'sac_fly': 'out',
    'sac_fly_double_play': 'out',
    'fielders_choice_out': 'out',

    # Walks / HBP / Interference
    'walk': 'walk',
    'hit_by_pitch': 'walk',
    'catcher_interf': 'walk',

    # Errors
    'field_error': 'error',

    # Other / Miscellaneous
    'truncated_pa': 'other',
    'fielders_choice': 'other',
    'sac_bunt': 'bunt',
}

# %%
# Apply the mapping
filtered_data['Pitch_outcome'] = filtered_data['Pitch_result'].map(outcome_mapping)

# Check for any outcomes not mapped
unmapped = filtered_data[filtered_data['Pitch_outcome'].isnull()]['Pitch_result'].unique()
print("Unmapped outcomes:", unmapped)
# Out:
# Unmapped outcomes: []
# /tmp/ipykernel_31/40195341.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Pitch_outcome'] = filtered_data['Pitch_result'].map(outcome_mapping)

# %%
filtered_data
# Out:
#      pitch_type  release_speed  inning  outs_when_up stand p_throws  balls  \
# 2210         SL           86.6       9             2     L        L      0
# 2288         SL           85.0       9             2     L        L      0
# 2304         FF           96.7       9             2     L        L      0
# 2398         FF           94.7       9             1     L        L      3
# 2456         FF           96.5       9             1     L        L      2
# ...         ...            ...     ...           ...   ...      ...    ...
# 4101         FF           91.4       1             0     R        L      1
# 4259         FF           91.1       1             0     R        L      1
# 4319         CH           81.8       1             0     R        L      1
# 4583         CH           81.7       1             0     R        L      1
# 4703         FF           90.6       1             0     R        L      0
#
#       strikes     Pitch_result Pitch_outcome
# 2210        2        field_out           out
# 2288        1    called_strike        strike
# 2304        0    called_strike        strike
# 2398        1        field_out           out
# 2456        1             ball          ball
# ...       ...              ...           ...
# 4101        2        strikeout           out
# 4259        2             foul        strike
# 4319        1             foul        strike
# 4583        0  swinging_strike        strike
# 4703        0             ball          ball
#
# [584974 rows x 10 columns]

# %%
filtered_data.drop(columns=['Pitch_result'],inplace=True)
# Out:
# /tmp/ipykernel_31/3795927089.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data.drop(columns=['Pitch_result'],inplace=True)

# %%
filtered_data
# Out:
#      pitch_type  release_speed  inning  outs_when_up stand p_throws  balls  \
# 2212         SL           86.6       9             2     L        L      0
# 2262         SL           85.0       9             2     L        L      0
# 2348         FF           96.7       9             2     L        L      0
# 2379         FF           94.7       9             1     L        L      3
# 2430         FF           96.5       9             1     L        L      2
# ...         ...            ...     ...           ...   ...      ...    ...
# 4054         FF           91.4       1             0     R        L      1
# 4196         FF           91.1       1             0     R        L      1
# 4440         CH           81.8       1             0     R        L      1
# 4475         CH           81.7       1             0     R        L      1
# 4651         FF           90.6       1             0     R        L      0
#
#       strikes Pitch_outcome
# 2212        2           out
# 2262        1        strike
# 2348        0        strike
# 2379        1           out
# 2430        1          ball
# ...       ...           ...
# 4054        2           out
# 4196        2        strike
# 4440        1        strike
# 4475        0        strike
# 4651        0          ball
#
# [584974 rows x 9 columns]

# %%
filtered_data.drop(columns=['stand','p_throws'],inplace=True)
# Out:
# /tmp/ipykernel_31/1404195280.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data.drop(columns=['stand','p_throws'],inplace=True)

# %%
filtered_data
# Out:
#      pitch_type  release_speed  inning  outs_when_up  balls  strikes  \
# 2210         SL           86.6       9             2      0        2
# 2288         SL           85.0       9             2      0        1
# 2304         FF           96.7       9             2      0        0
# 2398         FF           94.7       9             1      3        1
# 2456         FF           96.5       9             1      2        1
# ...         ...            ...     ...           ...    ...      ...
# 4101         FF           91.4       1             0      1        2
# 4259         FF           91.1       1             0      1        2
# 4319         CH           81.8       1             0      1        1
# 4583         CH           81.7       1             0      1        0
# 4703         FF           90.6       1             0      0        0
#
#      Pitch_outcome
# 2210           out
# 2288        strike
# 2304        strike
# 2398           out
# 2456          ball
# ...            ...
# 4101           out
# 4259        strike
# 4319        strike
# 4583        strike
# 4703          ball
#
# [584974 rows x 7 columns]

# %%
filtered_data.to_csv('filtered_pitching4.csv')

# %%
baseball_data = pd.read_csv('/kaggle/working/filtered_pitching4.csv')

# %%
baseball_data
# Out:
#         Unnamed: 0 pitch_type  release_speed  inning  outs_when_up  balls  \
# 0             2210         SL           86.6       9             2      0
# 1             2288         SL           85.0       9             2      0
# 2             2304         FF           96.7       9             2      0
# 3             2398         FF           94.7       9             1      3
# 4             2456         FF           96.5       9             1      2
# ...            ...        ...            ...     ...           ...    ...
# 584969        4101         FF           91.4       1             0      1
# 584970        4259         FF           91.1       1             0      1
# 584971        4319         CH           81.8       1             0      1
# 584972        4583         CH           81.7       1             0      1
# 584973        4703         FF           90.6       1             0      0
#
#         strikes Pitch_outcome
# 0             2           out
# 1             1        strike
# 2             0        strike
# 3             1           out
# 4             1          ball
# ...         ...           ...
# 584969        2           out
# 584970        2        strike
# 584971        1        strike
# 584972        0        strike
# 584973        0          ball
#
# [584974 rows x 8 columns]

# %%
numerical_cols = ['release_speed','inning']
categorical_cols = ['pitch_type','outs_when_up','balls','strikes']

# %%
X = filtered_data[['pitch_type','release_speed','inning','outs_when_up','balls', 'strikes']]
y= filtered_data['Pitch_outcome']

# %%
y.value_counts()
# Out:
# Pitch_outcome
# strike    239662
# ball      194972
# out       101896
# hit        32952
# walk       13643
# error        916
# other        555
# bunt         378
# Name: count, dtype: int64

# %%
# !pip install pyro-ppl
# Out:
# Collecting pyro-ppl
#   Downloading pyro_ppl-1.9.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.11/dist-packages (from pyro-ppl) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from pyro-ppl) (3.4.0)
# Collecting pyro-api>=0.1.1 (from pyro-ppl)
#   Downloading pyro_api-0.1.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.11/dist-packages (from pyro-ppl) (2.5.1+cu124)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.11/dist-packages (from pyro-ppl) (4.67.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.7->pyro-ppl) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.7->pyro-ppl) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.7->pyro-ppl) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.7->pyro-ppl) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.7->pyro-ppl) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.7->pyro-ppl) (2.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->pyro-ppl) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->pyro-ppl) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->pyro-ppl) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->pyro-ppl) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->pyro-ppl) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->pyro-ppl) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->pyro-ppl) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->pyro-ppl) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0->pyro-ppl)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0->pyro-ppl)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0->pyro-ppl)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0->pyro-ppl)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0->pyro-ppl)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0->pyro-ppl)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->pyro-ppl) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->pyro-ppl) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0->pyro-ppl)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->pyro-ppl) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->pyro-ppl) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0->pyro-ppl) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0->pyro-ppl) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.7->pyro-ppl) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.7->pyro-ppl) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.7->pyro-ppl) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.7->pyro-ppl) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.7->pyro-ppl) (2024.2.0)
# Downloading pyro_ppl-1.9.1-py3-none-any.whl (755 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 12.7 MB/s eta 0:00:00a 0:00:01
# Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.6 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.2 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 86.2 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: pyro-api, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, pyro-ppl
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pylibcugraph-cu12 24.12.0 requires pylibraft-cu12==24.12.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 24.12.0 requires rmm-cu12==24.12.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pyro-api-0.1.2 pyro-ppl-1.9.1

# %%
import torch
import pyro
import pyro.distributions as dist
from pyro.infer import SVI, Trace_ELBO
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import pandas as pd

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_cols),
        ('cat', OneHotEncoder(drop="first", sparse_output=False), categorical_cols)
    ])

X_preprocessed = preprocessor.fit_transform(X)

# %%
outcome_encoder = {v: i for i, v in enumerate(y.unique())}
y_encoded = y.map(outcome_encoder).values

# %%
n_classes = len(outcome_encoder)
n_classes
# Out:
# 8

# %%
y_encoded
# Out:
# array([0, 1, 1, ..., 1, 1, 2])

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
import torch
import pyro
import pyro.distributions as dist
from pyro.infer import SVI, Trace_ELBO
from torch.utils.data import TensorDataset, DataLoader
from sklearn.utils.class_weight import compute_class_weight
from pyro.infer import TraceMeanField_ELBO

# Define device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Move data to device
X_tensor = torch.tensor(X_preprocessed, dtype=torch.float32).to(device)
y_tensor = torch.tensor(y_encoded, dtype=torch.long).to(device)
dataset = TensorDataset(X_tensor, y_tensor)
loader = DataLoader(dataset, batch_size=32, shuffle=True)

class_weights = compute_class_weight(class_weight='balanced',
                                     classes=np.unique(y_encoded),
                                     y=y_encoded)
class_weights_tensor = torch.tensor(class_weights, dtype=torch.float32).to(device)

# Define Pyro model
def model(X, y=None):
    n_features = X.shape[1]
    n_classes = len(outcome_encoder)

    # Probabilistic weights on device
    #firsdt hidden
    w1 = pyro.sample("w1", dist.Normal(torch.zeros(n_features, 64, device=device),
                                       torch.ones(n_features, 64, device=device)).to_event(2))
    b1 = pyro.sample("b1", dist.Normal(torch.zeros(64, device=device),
                                       torch.ones(64, device=device)).to_event(1))

    #hidden layer
    w2 = pyro.sample("w2", dist.Normal(torch.zeros(64, 32, device=device),
                                       torch.ones(64, 32, device=device)).to_event(2))
    b2 = pyro.sample("b2", dist.Normal(torch.zeros(32, device=device),
                                       torch.ones(32, device=device)).to_event(1))
    # third hidden layer
    w3 = pyro.sample("w3", dist.Normal(torch.zeros(32, n_classes, device=device),
                                       torch.ones(32, n_classes, device=device)).to_event(2))
    b3 = pyro.sample("b3", dist.Normal(torch.zeros(n_classes, device=device),
                                       torch.ones(n_classes, device=device)).to_event(1))

    # Forward pass
    h1 = torch.relu(X @ w1 + b1)
    h2 = torch.relu(h1 @ w2 + b2)
    logits = h2 @ w3 + b3

    adjusted_logits = logits + torch.log(class_weights_tensor)

    # Output likelihood
    with pyro.plate("data", X.shape[0]):
        pyro.sample("obs", dist.Categorical(logits=adjusted_logits), obs=y)

    # Output likelihood
    #with pyro.plate("data", X.shape[0]):
        #pyro.sample("obs", dist.Categorical(logits=logits), obs=y)

# Guide
def guide(X, y=None):
    # First hidden layer
    w1_loc = pyro.param("w1_loc", torch.zeros(X.shape[1], 64, device=device))
    w1_scale = pyro.param("w1_scale", torch.ones(X.shape[1], 64, device=device), constraint=dist.constraints.positive)
    pyro.sample("w1", dist.Normal(w1_loc, w1_scale).to_event(2))

    b1_loc = pyro.param("b1_loc", torch.zeros(64, device=device))
    b1_scale = pyro.param("b1_scale", torch.ones(64, device=device), constraint=dist.constraints.positive)
    pyro.sample("b1", dist.Normal(b1_loc, b1_scale).to_event(1))

    # Second hidden layer
    w2_loc = pyro.param("w2_loc", torch.zeros(64, 32, device=device))
    w2_scale = pyro.param("w2_scale", torch.ones(64, 32, device=device), constraint=dist.constraints.positive)
    pyro.sample("w2", dist.Normal(w2_loc, w2_scale).to_event(2))

    b2_loc = pyro.param("b2_loc", torch.zeros(32, device=device))
    b2_scale = pyro.param("b2_scale", torch.ones(32, device=device), constraint=dist.constraints.positive)
    pyro.sample("b2", dist.Normal(b2_loc, b2_scale).to_event(1))

    # Output layer
    w3_loc = pyro.param("w3_loc", torch.zeros(32, len(outcome_encoder), device=device))
    w3_scale = pyro.param("w3_scale", torch.ones(32, len(outcome_encoder), device=device), constraint=dist.constraints.positive)
    pyro.sample("w3", dist.Normal(w3_loc, w3_scale).to_event(2))

    b3_loc = pyro.param("b3_loc", torch.zeros(len(outcome_encoder), device=device))
    b3_scale = pyro.param("b3_scale", torch.ones(len(outcome_encoder), device=device), constraint=dist.constraints.positive)
    pyro.sample("b3", dist.Normal(b3_loc, b3_scale).to_event(1))


# Training
pyro.clear_param_store()
svi = SVI(model, guide, pyro.optim.Adam({"lr": 0.01}), loss=TraceMeanField_ELBO()) #Trace_ELBO
for epoch in range(10):
    loss = 0
    for X_batch, y_batch in loader:
        loss += svi.step(X_batch, y_batch)
    print(f"Epoch {epoch}, Loss: {loss / len(dataset):.4f}")
# Out:
# Epoch 0, Loss: 9.5767

# %%
 
def predict(X):
    predictive = pyro.infer.Predictive(model, guide=guide, num_samples=100)
    samples = predictive(X)["obs"]
    probs = samples.float().mean(dim=0) / samples.shape[0]
    return probs

# %%
# Predict probabilities
X_test = X_tensor[:10]
probs = predict(X_test)
print("Predicted probabilities:", probs)
# Out:
# Predicted probabilities: tensor([0.0191, 0.0169, 0.0163, 0.0189, 0.0204, 0.0185, 0.0175, 0.0147, 0.0182,
#         0.0176])

# %%
y_pred = predict(X_tensor)
y_true = y_tensor.cpu()

from sklearn.metrics import accuracy_score, classification_report

# Accuracy
acc = accuracy_score(y_true, y_pred)
print(f"Accuracy: {acc:.4f}")

print(classification_report(y_true, y_pred, target_names=outcome_encoder.classes_))
